# %% [markdown]
# ____
# # Foundations of Data Science: Homework 1
#
# Welcome to your first homework assignment! This assignment will help you set up the necessary tools and familiarize yourself with course materials essential for your success in this Data Science course.
#
# ## Objectives
# By completing this homework, you will:
#
# * Familiarize yourself with course expectations and policies
# * Set up essential tools for the course
# * Assess your current Python knowledge
# * Begin engaging with course content

# %% [markdown]
# ____
# ## Tasks
#
# ### Read Course Materials (10 points)
#
# There are three important documents for this course. In this problem you will find them, read them and summarize them.
#  * Read the course syllabus (available in Teams and D2L as a PDF)
#     * In a new markdown cell, summarize the portions of the syllabus regarding attendance and late assignments.
#  * Read the AI policy (PDF)
#     * In a new markdown cell, summarize what you need to do to do when you use AI for an assignment.
#  * Read the AI guide to best practices (PDF)
#     * Also in a new markdown cell, give us some feedback on your experiences using AI in the past. How well did it work? What strategies have you developed for yourself, if any?
#
# ### GitHub Setup (10 points)
#
# You will use GitHub for your two projects. In addition to learning an important data science tool, this will allow you to retain all of your work beyond this course and share with people around the world.
#  * Create a GitHub account (if you don't already have one)
#  * If you are not already familiar with GH:
#     * [this](https://www.youtube.com/watch?v=tRZGeaHPoaw) is a great video - watch it slowly over the next week or so
#     * and, you can complete the GitHub Hello World guide: https://guides.github.com/activities/hello-world/
#  * Create a new repository for this course.
#
#  If you have any questions or problems with GH, please let us know!
#
# ### Initial and Python Surveys (10 points)
#
#  Complete the [initial survey](https://docs.google.com/forms/d/e/1FAIpQLSc86xvGnOgLzNUKC_wBhcXuhyRYqYLX7Vqhlw0I3Rga_5zSlw/viewform?usp=sf_link) _if you haven't already_.
#
#  Complete the Python coding knowledge survey: [click here](https://docs.google.com/forms/d/e/1FAIpQLSfiNjPuIISJH7RznayiZqwItHbgYGXZkruAbHQZnBeAODgg7A/viewform?usp=sf_link)
#
# Put a statement in a markdown cell that you have completed both of these.
#
# ### Textbook Reading (10 points)
#
#  Read Chapter 1 of "_Thinking Clearly with Data_"
#  * In a markdown cell, give a very high-level overview of the book
#    * what are its goals and how are those goals organized?
#    * what can you hope to get out of this book?
#  * Write a brief summary (200-300 words) of the key points from Chapter 1

# %% [markdown]
# ### Course Materials
# * **Course Syllabus Summary (Attendance and Late Submissions)**
#     * The policy surrounding attendance is strict, as in, missing a single class has 100% grade penalty on the ICA grades for that week, along with a 20% grade penalty on the week's homework assignments. Since ICA and HWA comprise a whopping 70% of the total grade, one should really not miss a class unless:
#         * They notified their absence for a valid reason well ahead of time.
#         * Sickness/Accident with valid medical proof. ***not mentioned in the booklet***
#     * Late Assignment Policy for the ICA and HWA are different.
#         * **ICA Late Submission**: All the members of the team receive no grade on a late submission, except for long assignments that may be granted an extension at the professor's discretion. The usual deadline for an ICA is the end of the class **\***.
#         * **HWA Late Submission**: Individuals would lose 25% of the total receivable grade for a one-day delay in assignment submission. For a two-day delay, they would lose 25% of the remaining grade after the first day's penalty. This pattern continues for a week. After a one-week delay, no credit will be awarded **\***.
# * **AI Usage Todo's**:
#     * Ensure that any AI generated content on code or assignments is properly cited wherever used, including the name, version and date of usage of the tool.
#     * Ensure that AI was only used as an assistance tool and not taking over my whole assignment.
#     * Ensure that any usage of AI is communicated to my team members during an ICA.
#     * Ensure that any AI written content is well-understood and that I am capable of explaining/defending the produced content.
#
# *  **AI Personal Experience**
#     * Two aspects of AI that can be extremely annoying.
#         * Its ability to remember - sometimes the AI misunderstands something I said in the thread, keeps a note of it and starts building the rest of the conversation on that one aspect. I can ask it to forget the context and it does, only to pull it back up out of nowhere in the future parts of the conversation.
#         * Contrasting the previous point, it has really horrible memory - We are having a code-related conversation and it gives me something that is obviously wrong and I correct it and it remembers it for a full second before giving the same horrible code as an output.
#     * My usual workaround to any coding-related bugs that AI is unable to answer is go back to the usual Google search. If the issue is context-related (something AI remembered and just won't let go) is to start a new chat. Thank ~~god~~ the devs for the ability to have multiple chat windows.
#     * Specifically mentioning the problem to the AI usually helps me out.
#     * I sometimes have a little fun with AI by asking to play pretense. I ask it to pretend to be a English professor or a child or a mean person to take inputs on my work.
#     * I sometimes make AI read through a huge chunk of text that I am reading, and later use it as a memory starter, or use it to create questions if I am trying to learn something.
#     * I ask it to create to-do lists of all the tasks I talked about throughout the conversation.
#
# The sections marked with **\*** were assisted by Gemini AI (latest) on 8/28/2024, however, only for fixing grammar.

# %% [markdown]
# ### Github Setup
#
# * You can find my GH [here](https://github.com/Vennamm).
# * Repository to CMSE course materials can be viewed [here](https://github.com/Vennamm/cmse_830).

# %% [markdown]
# ### Survey Completion Status
#
# * Initial Survey - &#x2713;
# * Python Survey - &#x2713;

# %% [markdown]
# ### Textbook Reading
#
# The first chapter revolves around the idea that before we start the analysis for any given data, we need to stop ourselves and think about what the data is, and where it comes from. We need to see beyond what the data provides, and in general, develop a sense of thinking "Am I looking at this data in the right manner?". We need to ask ourselves how accurate an analysis is, upon seeing one. Once we get an idea of the context behind the data, and understand the ambiguity of any analysis, that is when we use the technical side of a data analysis to prove our hypothesis. Whatever idea that we develop initially upon the received data, we need to view it with skepticism. We need to try and prove ourselves right instead of introducing a bias OR misrepresenting the data. The author is trying to ensure that we don't lose the power of common sense and analytical thinking before we jump and start doing the fancy statistical problem-solving. With the right understanding of the data, we should start any data analysis to avoid the pitfall of misrepresenting it.
#
# **What are the goals of the book and how are they organized?**
# As the book's name suggests, the goal of the book is to get the reader to think clearly with data, in a data-driven world where we can often toss the clear thinking for the technical thinking. To make this point, the book uses real life examples of bad decisions driven by misinterpreted data, and the good decisions made by clear thinking with data. The book tries to reintroduce and reinforce the concepts of understanding data, because that is where grave errors are bound to happen. The book is divided into four parts starting from estabilishing a common language, and ending with a deep-dive into statistical relationships and their impact on the decisions we make.
#
# **What can I hope to get out of this book?**
# When I started learning data science, I enrolled myself in various courses and referred to Kaggle notebooks. The main struggle I faced in both was that I could not figure why they were using a certain statistical concept to analyse the data and the model. Eventually, I just used these tools as blindly as I read, without knowing what the data was trying to tell. As daunting as I find it, I find myself often interested in relearning high-school statistics to figure out what they mean in relation to data. The moment I read through the first words of the book, I was thinking to myself that this is exactly what I am looking for:
#
# *A way to understand the data, when a relation is significant, and how I can actually make decisions out of my working data knowing exactly what I am doing.*

# %% [markdown]
# ____
# ## Streamlit Setup and Test (10 points)
#
#  We will develop web apps using [Streamlit](https://streamlit.io) throughout the semester and your projects will use this tool.
#
# Install Streamlit on your computer, follow the installation guide: https://docs.streamlit.io/library/get-started/installation
#
# Note that Streamlit is run from the command line. [Read this.](https://docs.streamlit.io/get-started/fundamentals/main-concepts) Bookmark this documentation for later in the semester.
#
# Let us know if you have any issues with this.
#
# Next, create .py files with the following two codes and ensure that these run on your computer. It is not necessary that you understand what they do; the goal here is:
# 1. to get Streamlit operational on your computer, and let us know where the problems are,
# 2. and, see what Streamlit does and how it functions.
#
# Include screen shots to show that you got this to work.

# %%
# Streamlit Code 1

import streamlit as st

st.write("Hello World!")

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Streamlit Code 2

import streamlit as st
import pandas as pd
import numpy as np

chart_data = pd.DataFrame(
   np.random.randn(20, 3),
   columns=['a', 'b', 'c'])

st.line_chart(chart_data)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ____
# ## Submission
#
# Submit this notebook to D2L. Do not submit anything else (e.g., a PDF)!
#
# ____
# ## Due Date
#
# This assignment is due Sunday, September 1 at midnight.
